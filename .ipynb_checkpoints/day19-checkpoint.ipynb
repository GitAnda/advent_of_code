# %%
f = open('day19.txt')
input_puzzle = f.read().split('\n\n')

messages = input_puzzle[1].split('\n')
rules_list = input_puzzle[0].split('\n')

# %%
def has_digits(strings):
    for string in strings:
        if any(char.isdigit() for char in string):
            return True
    return False

def get_known_rules(dict_rules):
    known_rules = set()
    for rule in dict_rules.keys():
        hasDigits = True
        for subrule in dict_rules[rule]:
            if not(has_digits(dict_rules[rule])):
                hasDigits = False
                break
        if not(hasDigits):
            known_rules.add(str(rule))
    return known_rules

def reduce_spaces(dict_rules):
    for rule in dict_rules.keys():
        for i,subrule in enumerate(dict_rules[rule]):
            dict_rules[rule][i] = subrule.replace('a a', 'aa').replace('a b', 'ab').replace('b a', 'ba').replace('b b', 'bb')
    return dict_rules

def remove_duplicates(dict_rules):
    for rule in dict_rules.keys():
        dict_rules[rule] = list(dict.fromkeys(dict_rules[rule]))
    return dict_rules

def initialise_dict(rules_list):
    dict_rules = {}
    for rule in rules_list:
        rule = rule.split(':')
        dict_rules[int(rule[0])] = (rule[1]+' ').split('|')
        
    return dict_rules

def run():
    dict_rules = initialise_dict(rules_list)
    cont = True
    count = 0
    while cont:
#     for _ in range(12): 
        known_rules = get_known_rules(dict_rules)
        cont = False

        for rule in dict_rules.keys():
            if has_digits(dict_rules[rule]):
                cont = True
                
                testAdd = []
                testRemove = []
                
                for known_rule in known_rules:
                    for x in dict_rules[rule]:
                        if ' '+known_rule+' ' in x:
                            for y in dict_rules[int(known_rule)]:
                                testAdd.append(x.replace(' '+known_rule+' ', y))
                             
                            testRemove.append(x)

                testRemove = list(dict.fromkeys(testRemove))
                testAdd = list(dict.fromkeys(testAdd))
                for x in testRemove:
                    dict_rules[rule].remove(x)
                for x in testAdd:
                    dict_rules[rule].append(x) 
    
    dict_rules = reduce_spaces(reduce_spaces(dict_rules))   
    dict_rules = remove_duplicates(dict_rules)
    
    return dict_rules
        
dict_result = run()

# %%
count = 0 
for m in messages:
    if ' '+m+' ' in dict_result[0]:
        count += 1
        
count
# Out:
# 0 bbaabbabbbaaabbbbbaaaaab
# 1 aaabbaaaaabbabbaabaababa
# 2 bbabbabbaabbabbbbbabbaab
# 3 bbabbababbbbbabbbabbaaba
# 4 babaabbbbbababaabbbabbaa
# 5 aaaaaabbaaabbabaabaabaaa
# 6 ababaabbbaabbbbaabbbabab
# 7 aaabaabbaaabaaaaaaaabbba
# 8 bbbbabaabbaabbbabababbab
# 9 bbbababbbbaaabbbbbbaaaba
# 10 bbbabaaaabaabbaaaababbaa
# 11 abbaaabbbbbabbbbbabababa
# 12 baaabbabababbabbabbaabab
# 13 bababaaabaaaabbbaaababbb
# 14 babbaabbaabaababaaaaaaab
# 15 aabbaaaabaabbbbaabbbbaab
# 16 babbbbbbbaabaaaaabababab
# 17 abbbaaaaaabababbbbaaabab
# 18 bbaabbbaabaabbbaabaaabab
# 19 abbaaaabbbabbabaababaaaa
# 20 babbaaaaaaababbababaaaaa
# 21 bbbbaabbbbaaabbabbaababa
# 22 ababbbabaabbbabbabaababa
# 23 bbaabbabbaabbbaabbbbabba
# 24 aabbbbaabbbbbabbbbbabbaa
# 25 bbabababaabaaaabaaaabbaa
# 26 bbbabaaaabbbaaaaaabbbbba
# 27 babbbabaaababaabbababbba
# 28 bbbbaabbbbababaababaabaa
# 29 baababaabaababbabbbbabbb
# 108 babbbbbbaabbaaaabaabbbab
# 109 bbaabbabbaabbaaabaaaabaa
# 110 baababbabaababbabaaaaabb
# 111 abaaabbbabbababbaabbbaaa
# 112 babbbbabababaaabaabbbaaa
# 113 abaabbaaaaababbabababbbb
# 114 bbbbaaabbbabbabaabbbbaaa
# 115 ababaaabbbababababbbabba
# 116 bbbabbbbaaaaaabbaaaababa
# 117 baabbbbbbbbbaaabbababbaa
# 118 bbabbababaabababbbaaabaa
# 119 aabbabaababaabbaabbbabba
# 120 abbbabaabababaabababaaaa
# 121 bbaabbabbbabbbaabbbaabbb
# 122 abbbbabbbaabbbbaabbabaaa
# 123 aabbabaabaabbbaababbabaa
# 124 babbbbbbbaabaaababaaabab
# 125 baaaaabaaabababbbabaaaaa
# 126 aaaaaababbabababbbaababa
# 127 abbabbbabaabaaabbbbbbbba
# 128 bbaaaabbabababbbbbbbbaab
# 129 baabaaabbabbaabbaabababa
# 130 babbbbbabaabaabbbabaaaaa
# 131 bababaaaaaabaabbbabababa
# 132 baaaabbaaaababaaabbaabbb
# 133 aababaabaababaababbaabab
# 134 abbaabbaabbaabbababbabab
# 135 ababaaababbbbbbaaababbbb
# 136 baaabaabbabbbbaaaaaaabbb
# 137 ababaabbaaabbabbaaaaabab
# 138 abbabbbaaaabbaaaabababab
# 139 aabaababababaabbbabbabaa
# 140 abaaaabbbaabaaabaaabbbaa
# 141 aabbabbbbbbaaabbaaaabbab
# 142 ababaabbaabbaaaabbaaaaab
# 143 abaabbbaaaabbbbbabaabbab
# 144 babaabbbbaababaaaabbaaab
# 145 aabbabaaababbbaabbaaabab
# 146 abbaaaabbabababbbbbbbbbb
# 147 baabaaaaaaaabaababbaabbb
# 148 aabaabbbbabbaabbbaababbb
# 149 abbabbbaabababaaababbbba
# 150 aaaabbbbbbaabbabaabbaabb
# 151 baabaaababbbaabaabbbbbaa
# 152 abbaaabaaabaababbbabaaaa
# 153 aabbbbaaaaaaaababaaababa
# 154 bbaabbabababaababaaaaaaa
# 155 bbbaababbabbbbbabbbbaaaa
# 156 ababbbababaabbaabababbab
# 157 aaabbaaaabbaaabbabbaabab
# 158 babbbabababbbababbbabbba
# 159 abbbbabbbbababaaabaabaab
# 160 babaabbaaaaabbbbabbbbaab
# 161 aabbaaaaabaabbbbabaaaaab
# 162

# %%
# rule_42 = dict_result[42]
# rule_31 = dict_result[31]

# print('42:', rule_42)
# print('31:', rule_31)

# count = 0
# for m in messages:
#     count_42 = 0 
#     count_31 = 0
    
#     for i in range(len(m)//8):
#         if ' '+m[i*8:(i+1)*8]+' ' in dict_result[42]:
#             count_42 += 1
#         elif ' '+m[i*8:(i+1)*8]+' ' in dict_result[31]:
#             count_31 += 1
    
#     if count_42 > count_31:
#         count += 1

count = 0
for m in messages:    
    if ' '+m[:8]+' ' in dict_result[42] and ' '+m[8:16]+' ' in dict_result[42] and ' '+m[16:24]+' ' in dict_result[31] and len(m)==24:
        print(count, m)
        count += 1

count
# dict_result[0]
# Out:
# 0 bbaabbabbbaaabbbbbaaaaab
# 1 aaabbaaaaabbabbaabaababa
# 2 bbabbabbaabbabbbbbabbaab
# 3 bbabbababbbbbabbbabbaaba
# 4 babaabbbbbababaabbbabbaa
# 5 aaaaaabbaaabbabaabaabaaa
# 6 ababaabbbaabbbbaabbbabab
